# %%
1+1
# Out:
# 2

# %%
1+1
# Out:
# [1] 2

# %%
library(rtracklayer)
# Out:
# Error in library(rtracklayer): there is no package called ‘rtracklayer’
# Traceback:
#
# 1. library(rtracklayer)

# %%
options(BioC_mirror="https://mirrors.tuna.tsinghua.edu.cn/bioconductor")

# %%
BiocManager::install("rtracklayer")
# Out:
# Warning message in file(con, "r"):
# “URL 'https://bioconductor.org/config.yaml': status was 'SSL connect error'”
# Bioconductor version 3.12 (BiocManager 1.30.10), R 4.0.2 (2020-06-22)
#
# Installing package(s) 'rtracklayer'
#
# also installing the dependencies ‘Rhtslib’, ‘Rsamtools’, ‘GenomicAlignments’
#
#
# Warning message in install.packages(...):
# “installation of package ‘Rhtslib’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘Rsamtools’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘GenomicAlignments’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘rtracklayer’ had non-zero exit status”
# Installation path not writeable, unable to update packages: checkpoint, curl,
#   doParallel, iterators, jsonlite, MASS, R6, Rcpp, RUnit
#
# Old packages: 'BH', 'boot', 'brio', 'caTools', 'clipr', 'cowplot', 'cpp11',
#   'crosstalk', 'data.table', 'DBI', 'DelayedArray', 'devtools', 'diffobj',
#   'dplyr', 'DT', 'fansi', 'generics', 'ggplot2', 'ggrepel', 'git2r', 'hms',
#   'htmltools', 'httr', 'IRdisplay', 'magrittr', 'Matrix', 'pbdZMQ', 'plotrix',
#   'RcppArmadillo', 'repr', 'rlang', 'RSQLite', 'rstudioapi', 'tibble',
#   'usethis', 'withr', 'xfun'

# %%
install.packages(c("checkpoint", "doParallel", "iterators"))
# Out:
# Installing packages into ‘/home/louies/R/x86_64-pc-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages(c("checkpoint", "doParallel", "iterators")):
# “installation of package ‘doParallel’ had non-zero exit status”

# %%
install.packages(c("jsonlite", "MASS", "R6", "Rcpp", "RUnit"))
# Out:
# Installing packages into ‘/home/louies/R/x86_64-pc-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages(c("jsonlite", "MASS", "R6", "Rcpp", "RUnit")):
# “installation of package ‘jsonlite’ had non-zero exit status”

# %%
BiocManager::install("rtracklayer")
# Out:
# Bioconductor version 3.12 (BiocManager 1.30.10), R 4.0.2 (2020-06-22)
#
# Installing package(s) 'rtracklayer'
#
# also installing the dependencies ‘Rhtslib’, ‘Rsamtools’, ‘GenomicAlignments’
#
#
# Warning message in install.packages(...):
# “installation of package ‘Rhtslib’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘Rsamtools’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘GenomicAlignments’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘rtracklayer’ had non-zero exit status”
# Installation path not writeable, unable to update packages: curl, doParallel,
#   jsonlite, RUnit
#
# Old packages: 'BH', 'boot', 'brio', 'caTools', 'checkpoint', 'clipr',
#   'cowplot', 'cpp11', 'crosstalk', 'data.table', 'DBI', 'DelayedArray',
#   'devtools', 'diffobj', 'dplyr', 'DT', 'fansi', 'generics', 'ggplot2',
#   'ggrepel', 'git2r', 'hms', 'htmltools', 'httr', 'IRdisplay', 'iterators',
#   'magrittr', 'MASS', 'Matrix', 'pbdZMQ', 'plotrix', 'R6', 'Rcpp',
#   'RcppArmadillo', 'repr', 'rlang', 'RSQLite', 'rstudioapi', 'tibble',
#   'usethis', 'withr', 'xfun'
