# %%
motorcycle = ['honda', 'yamaha', 'suzuki']

# %%
print(motorcycle)
# Out:
# ['honda', 'yamaha', 'suzuki']

# %%
motorcycle.append('ducati')

# %%
print(motorcycle)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati', 'ducati']

# %%
motorcycle.insert(0,'ducati')
print(motorcycle)
# Out:
# ['ducati', 'ducati', 'honda', 'yamaha', 'suzuki', 'ducati', 'ducati']

# %%
del motorcycle[0]
print(motorcycle)
# Out:
# ['ducati', 'honda', 'yamaha', 'suzuki']

# %%
motorcycle.remove('honda')
print(motorcycle)
# Out:
# ['yamaha', 'suzuki']

# %%
print("\nA")
# Out:
# A

# %%
cars =['bmw', 'audi', 'toyota', 'subaru']

# %%
print(cars)
# Out:
# ['bmw', 'audi', 'toyota', 'subaru']

# %%
cars.sort()
print(cars)
# Out:
# ['audi', 'bmw', 'subaru', 'toyota']

# %%
cars.sort(reverse=True)
print(cars)
# Out:
# ['toyota', 'subaru', 'bmw', 'audi']

# %%
cars =['bmw', 'audi', 'toyota', 'subaru']
print(cars)
# Out:
# ['bmw', 'audi', 'toyota', 'subaru']

# %%
cars.reverse()
print(cars)
# Out:
# ['subaru', 'toyota', 'audi', 'bmw']

# %%
len(cars)
# Out:
# 4

# %%
print(cars[-1])
# Out:
# bmw
